# %% [markdown]
# <a href="https://colab.research.google.com/github/Samraddhi-Gupta/Perceptron-trick/blob/main/perceptron_trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification #to generate synthetic datasets that can be used for classification tasks
import numpy as np # for numerical
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)
#n_samples=100: Creates a dataset with 100 samples.
#n_ffeatures=2: Each sample will have 2 features.
#n_informative=1: Only 1 of the 2 features is informative for classification.
#n_redundant=0: No redundant features (features that are linear combinations of the informative features).
#n_classes=2: There are 2 distinct classes in the dataset.
#n_clusters_per_class=1: Each class will have 1 cluster of points.
#andom_state=41: Controls the randomness of the dataset generation for reproducibility.
#hypercube=False: Points will not be drawn from a hypercube (a generalization of a cube to more dimensions).
#class_sep=10: The classes will be well-separated by a large margin, making the classification problem relatively easy.

# %%
import matplotlib.pyplot as plt #creating a variety of static, animated, and interactive plots in Python

# %%
plt.figure(figsize=(10,6)) #plt.figure(figsize=(10,6)): Creates a new figure with a size of 10 inches by 6 inches.
#10 is the width, and 6 is the height.
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100) #plt.scatter(X[:,0], X[:,1], c=y, cmap='winter', s=100): Plots a scatter plot
#scatter: A function in matplotlib.pyplot that creates a scatter plot. A scatter plot shows the relationship between two variables by displaying individual data points.
#X[:,0]: The first column of the X array. X is assumed to be a 2D array (or matrix) where each row is a data point and each column represents a feature. [:,0] selects all rows of the first column.
#X[:,1]: The second column of the X array. [:,1] selects all rows of the second column.
#c=y: A parameter that specifies the color of each point in the scatter plot. y is an array of values used to determine the color of each point.
#cmap='winter': The colormap used to map the values in y to colors. 'winter' is a predefined colormap in matplotlib that ranges from blue to green.
#s=100: The size of each point in the scatter plot. 100 specifies the area of the markers in points squared.

# %%
def perceptron(X,y):
    X = np.insert(X,0,1,axis= 1)
    weights - np.ones(X.shape[1])
    lr = 0.1
    for i in range(1000):
        j = np.random.radiant(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
    return weights[0],weights[1:]
#def: This keyword is used to define a new function in Python.
#perceptron: The name of the function.
#X: The input feature matrix. Each row represents a data point and each column represents a feature.
#y: The target values (labels) for each data point in X.
#np.insert(X, 0, 1, axis=1): Inserts a column of ones at the beginning of the feature matrix X. This column represents the bias term (intercept) for the perceptron.
#axis=1: Specifies that the insertion is along columns (i.e., it adds a new column).

# %%
def step(z):
    return 1 if z>0 else 0

# %%
import numpy as np

def step(x):
    return 1 if x >= 0 else 0

def perceptron(X, y):
    # Add bias term to feature matrix X
    X = np.insert(X, 0, 1, axis=1)

    # Initialize weights to ones
    weights = np.ones(X.shape[1])

    # Learning rate
    lr = 0.1

    # Training loop
    for i in range(1000):
        # Randomly select an index
        j = np.random.randint(0, X.shape[0])

        # Compute the prediction
        y_hat = step(np.dot(X[j], weights))

        # Update weights
        weights = weights + lr * (y[j] - y_hat) * X[j]

    # Return the intercept and coefficients
    return weights[0], weights[1:]

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [ 0.6 -0.4]
# 1.3877787807814457e-16

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
